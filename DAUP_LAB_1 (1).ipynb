# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('insurance.csv')

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
print(max(data['children']))
# Out:
# 5

# %%
#vector
age_vector=data['age']
bmi_vector=data['bmi']
print(age_vector)
print(bmi_vector)
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64
# 0       27.9
# 1       33.8
# 2       33.0
# 3       22.7
# 4       28.9
#         ...
# 1333    31.0
# 1334    31.9
# 1335    36.9
# 1336    25.8
# 1337    29.1
# Name: bmi, Length: 1338, dtype: float64

# %%
#factors
gender_factor=data['sex']
smoker_factor=data['smoker']
print(gender_factor)
print(smoker_factor)
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: sex, Length: 1338, dtype: object
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
data.replace('male',1,inplace=True)
data.replace('female',0,inplace=True)
data.replace('yes',1,inplace=True)
data.replace('no',0,inplace=True)
data.replace('northeast',0,inplace=True)
data.replace('northwest',1,inplace=True)
data.replace('southeast',2,inplace=True)
data.replace('southwest',3,inplace=True)
# Out:
# <ipython-input-9-db7229bce4f3>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace('female',0,inplace=True)
# <ipython-input-9-db7229bce4f3>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace('no',0,inplace=True)
# ...

# %%
#list
ls=data.values.tolist()
print(ls)
# Out:
# [[19.0, 0.0, 27.9, 0.0, 1.0, 3.0, 16884.92], [18.0, 1.0, 33.8, 1.0, 0.0, 2.0, 1725.55], [28.0, 1.0, 33.0, 3.0, 0.0, 2.0, 4449.46], [33.0, 1.0, 22.7, 0.0, 0.0, 1.0, 21984.47], [32.0, 1.0, 28.9, 0.0, 0.0, 1.0, 3866.86], [31.0, 0.0, 25.7, 0.0, 0.0, 2.0, 3756.62], [46.0, 0.0, 33.4, 1.0, 0.0, 2.0, 8240.59], [37.0, 0.0, 27.7, 3.0, 0.0, 1.0, 7281.51], [37.0, 1.0, 29.8, 2.0, 0.0, 0.0, 6406.41], [60.0, 0.0, 25.8, 0.0, 0.0, 1.0, 28923.14], [25.0, 1.0, 26.2, 0.0, 0.0, 0.0, 2721.32], [62.0, 0.0, 26.3, 0.0, 1.0, 2.0, 27808.73], [23.0, 1.0, 34.4, 0.0, 0.0, 3.0, 1826.84], [56.0, 0.0, 39.8, 0.0, 0.0, 2.0, 11090.72], [27.0, 1.0, 42.1, 0.0, 1.0, 2.0, 39611.76], [19.0, 1.0, 24.6, 1.0, 0.0, 3.0, 1837.24], [52.0, 0.0, 30.8, 1.0, 0.0, 0.0, 10797.34], [23.0, 1.0, 23.8, 0.0, 0.0, 0.0, 2395.17], [56.0, 1.0, 40.3, 0.0, 0.0, 3.0, 10602.39], [30.0, 1.0, 35.3, 0.0, 1.0, 3.0, 36837.47], [60.0, 0.0, 36.0, 0.0, 0.0, 0.0, 13228.85], [30.0, 0.0, 32.4, 1.0, 0.0, 3.0, 4149.74], [18.0, 1.0, 34.1, 0.0, 0.0, 2.0, 1137.01]
# ...

# %%
#matrics
mat=data.values
print(mat)
# Out:
# [[1.900000e+01 0.000000e+00 2.790000e+01 ... 1.000000e+00 3.000000e+00
#   1.688492e+04]
#  [1.800000e+01 1.000000e+00 3.380000e+01 ... 0.000000e+00 2.000000e+00
#   1.725550e+03]
#  [2.800000e+01 1.000000e+00 3.300000e+01 ... 0.000000e+00 2.000000e+00
#   4.449460e+03]
#  ...
#  [1.800000e+01 0.000000e+00 3.690000e+01 ... 0.000000e+00 2.000000e+00
#   1.629830e+03]
#  [2.100000e+01 0.000000e+00 2.580000e+01 ... 0.000000e+00 3.000000e+00
#   2.007950e+03]
#  [6.100000e+01 0.000000e+00 2.910000e+01 ... 1.000000e+00 1.000000e+00
#   2.914136e+04]]

# %%
#data frames
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    0  27.9         0       1       3  16884.92
# 1   18    1  33.8         1       0       2   1725.55
# 2   28    1  33.0         3       0       2   4449.46
# 3   33    1  22.7         0       0       1  21984.47
# 4   32    1  28.9         0       0       1   3866.86

# %% [markdown]
# # **Part-2: Scatter plot**

# %%
#part -2
#Generate a scatter plot
plt.scatter(age_vector,smoker_factor)
plt.xlabel('age')
plt.ylabel('smoker')
# Out:
# Text(0, 0.5, 'smoker')

# %% [markdown]
# # **Part-3: Filter data Smokers Between 20 and 40**

# %%
smokers_data = data[data['smoker'] == 1]
age_data = data[(data['age'] >= 20) & (data['age'] <= 40)]

print("Smokers Data:")
print(smokers_data)

print("\nAge Data (20-40):")
print(age_data)
plt.figure(figsize=(10, 6))
plt.scatter(age_data['age'], age_data['smoker'], c='blue', marker='*')
plt.xlabel('Age')
plt.ylabel('Smoker (1 for yes, 0 for no)')
plt.title('Scatter Plot of Age vs Smoker Status')
plt.grid(True)
plt.show()

age_count = len(age_data)
print(f"Number of people in the specified age range: {age_count}")
# Out:
# Smokers Data:
#       age  sex   bmi  children  smoker  region  expenses
# 0      19    0  27.9         0       1       3  16884.92
# 11     62    0  26.3         0       1       2  27808.73
# 14     27    1  42.1         0       1       2  39611.76
# 19     30    1  35.3         0       1       3  36837.47
# 23     34    0  31.9         1       1       0  37701.88
# ...   ...  ...   ...       ...     ...     ...       ...
# 1313   19    0  34.7         2       1       3  36397.58
# 1314   30    0  23.7         3       1       1  18765.88
# 1321   62    1  26.7         0       1       0  28101.33
# 1323   42    0  40.4         2       1       2  43896.38
# 1337   61    0  29.1         0       1       1  29141.36
#
# [274 rows x 7 columns]
#
# Age Data (20-40):
#       age  sex   bmi  children  smoker  region  expenses
# 2      28    1  33.0         3       0       2   4449.46
# 3      33    1  22.7         0       0       1  21984.47
# ...

# %% [markdown]
# # **Max Age and Bmi**

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.665471     1.094918     0.204783
# std      14.049960     0.500160     6.098382     1.205493     0.403694
# min      18.000000     0.000000    16.000000     0.000000     0.000000
# 25%      27.000000     0.000000    26.300000     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.700000     2.000000     0.000000
# max      64.000000     1.000000    53.100000     5.000000     1.000000
#
#             region      expenses
# count  1338.000000   1338.000000
# mean      1.515695  13270.422414
# std       1.104885  12110.011240
# min       0.000000   1121.870000
# 25%       1.000000   4740.287500
# 50%       2.000000   9382.030000
# 75%       2.000000  16639.915000
# max       3.000000  63770.430000

# %%
plt.scatter(age_vector,data['expenses'])
plt.xlabel('age')
plt.ylabel('expenses')
# Out:
# Text(0, 0.5, 'expenses')

# %%
# Part (c) - Expenses of smokers and non-smokers (Bar Plot)
import seaborn as sns
expenses_grouped = data.groupby('smoker')['expenses'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='smoker', y='expenses', data=expenses_grouped, palette='pastel')
plt.title('Average Expenses: Smokers vs Non-Smokers')
plt.xlabel('Smoker (Yes/No)')
plt.ylabel('Average Expenses')
plt.show()
# Out:
# <ipython-input-18-1d0ac8e79bba>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='smoker', y='expenses', data=expenses_grouped, palette='pastel')

# %%
# Scatter plot between age and expenses
plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='expenses', data=data, color='green', s=50, alpha=0.6)
plt.title('Scatter Plot: Age vs Expenses')
plt.xlabel('Age')
plt.ylabel('Expenses')
plt.grid(True)
plt.show()
